# %% [markdown]
# This notebook demonstrates the distribution of true vs estimated treatment effect and the bias when not accounting for network structure.

# %%
# %load_ext autoreload
# %autoreload 

import pandas as pd
from methods.methods_est import calculate_lr_results
from methods.constants import DataGenerationSettings
dgp_settings = DataGenerationSettings()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# | Network   | Neigbour influence   | Effect difference  |
# |:-------|:--------:|-------:|
# | Barabasi-Albert (n_edges=3) | 0.3   | 6.2% |
# | Barabasi-Albert (n_edges=3) | 0.6   | 8.4% |
# | Barabasi-Albert (n_edges=3) | 0.9   | 20% |
# | Watts Srogatz (n_edges=3, p=0.7) | 0.3   | 8% |
# | Watts Srogatz (n_edges=3, p=0.7) | 0.6   | 15% |
# | Watts Srogatz (n_edges=3, p=0.7) | 0.9   | 148% |
# | Erdos Renyi (n_edges=3, p=0.1) | 0.3   | 40% |
# | Erdos Renyi (n_edges=3, p=0.1) | 0.6   | 8% |
# | Erdos Renyi (n_edges=3, p=0.1) | 0.9   | 38% |

# %%
df = pd.read_parquet('data/individ_data/individ_data_1000_0.6.parquet')
calculate_lr_results(df, dgp_settings.n_sim, dgp_settings.n_features)
# Out:
# 100%|██████████| 1000/1000 [00:02<00:00, 369.72it/s]
# Pecrentage difference between true and estimated effect: 6.232

# %%
df = pd.read_parquet('data/individ_data/individ_data_1000_0.9.parquet')
calculate_lr_results(df, dgp_settings.n_sim, dgp_settings.n_features)
# Out:
# 100%|██████████| 1000/1000 [00:02<00:00, 350.47it/s]
# Pecrentage difference between true and estimated effect: 8.401

# %%
# watts_strogatz_graph 0.7

# %%
df = pd.read_parquet('data/individ_data/individ_data_500_0.3.parquet')
calculate_lr_results(df, dgp_settings.n_sim, dgp_settings.n_features)
# Out:
# 100%|██████████| 100/100 [00:00<00:00, 360.51it/s]
# Pecrentage difference between true and estimated effect: 15.238

# %%
df = pd.read_parquet('data/individ_data/individ_data_500_0.6.parquet')
calculate_lr_results(df, dgp_settings.n_sim, dgp_settings.n_features)
# Out:
# ...
# 100%|██████████| 100/100 [00:00<00:00, 259.50it/s]
# Pecrentage difference between true and estimated effect: 20.095

# %%
df = pd.read_parquet('data/individ_data/individ_data_100_0.9.parquet')
calculate_lr_results(df, dgp_settings.n_sim, dgp_settings.n_features)
# Out:
# 100%|██████████| 100/100 [00:00<00:00, 508.18it/s]
# Pecrentage difference between true and estimated effect: 148.359

# %%
# erdos_renyi_graph 0.1
df = pd.read_parquet('data/individ_data/individ_data_erdos_renyi_graph_100_0.3.parquet')
calculate_lr_results(df, dgp_settings.n_sim, dgp_settings.n_features)
# Out:
# 100%|██████████| 100/100 [00:00<00:00, 541.20it/s]
# Pecrentage difference between true and estimated effect: 40.621

# %%
df = pd.read_parquet('data/individ_data/individ_data_erdos_renyi_graph_100_0.6.parquet')
calculate_lr_results(df, dgp_settings.n_sim, dgp_settings.n_features)
# Out:
# 100%|██████████| 100/100 [00:00<00:00, 545.52it/s]
# Pecrentage difference between true and estimated effect: 7.561

# %%
df = pd.read_parquet('data/individ_data/individ_data_erdos_renyi_graph_100_0.9.parquet')
calculate_lr_results(df, dgp_settings.n_sim, dgp_settings.n_features)
# Out:
# 100%|██████████| 100/100 [00:00<00:00, 477.72it/s]
# Pecrentage difference between true and estimated effect: 38.534
